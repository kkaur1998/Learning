# %%
product_list = {"1111":"pencil","1112":"pen","1113":"copy","1114":"binding","1115":"eraser","1116":"sharpner",
               "1117":"prints","1118":"stickers","1119":"notebook","1120":"file"}
price_list = {"1111":10,"1112":20,"1113":30,"1114":40,"1115":5,"1116":6,
               "1117":20,"1118":25,"1119":40,"1120":70}
quantity_list = {"1111":2000,"1112":24000,"1113":8000,"1114":7000,"1115":6000,"1116":4000,
               "1117":9000,"1118":6000,"1119":20000,"1120":10000}

product = {"1111":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1112":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1113":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1114":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1115":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1116":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1117":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1118":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1119":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1120":{"name":"pencil",
                  "price":10,
                  "quantity": 2000}}
class Company:
    def __init__(self):
        self.min_limit= 200
        self.max_limit= 5000
    def get_prodid(self,product):
        global product_list
        for i in list(product_list.keys()):
            if(product_list[i]==product):
                self.key = i
                return self.key
        else:
            return False
    def check_quantity(self,quantity):
        global quantity_list
        if(quantity>=self.min_limit and quantity<=self.max_limit):
            return True
        else:
            return False
    def calc_price(self,product,quantity):
        global product_list
        global quantity_list
        self.price = price_list[product]*quantity
        quantity_list[product] -= quantity
        return self.price
    
obj = Company()
product = input("enter the product you want to buy: ")
prodid = obj.get_prodid(product)
if(prodid != False):
    quantity = int(input("enter quantity of product"))
    if(obj.check_quantity(quantity)):
        price= obj.calc_price(prodid,quantity)
        print("your bill is: ", price)
    else:
        print("Quantity should be between 200 - 5000")
else:
    print("please try to order the item from the below list")
# Out:
# enter the product you want to buy: pen
# enter quantity of product20
# Quantity should be between 200 - 5000

# %%
product = {"1111":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1112":{"name":"pen",
                  "price":20,
                  "quantity": 24000},
           "1113":{"name":"copy",
                  "price":30,
                  "quantity": 8000},
           "1114":{"name":"binding",
                  "price":40,
                  "quantity": 7000},
           "1115":{"name":"eraser",
                  "price":5,
                  "quantity": 6000},
           "1116":{"name":"sharpner",
                  "price":6,
                  "quantity": 4000},
           "1117":{"name":"prints",
                  "price":20,
                  "quantity": 9000},
           "1118":{"name":"stickers",
                  "price":25,
                  "quantity": 6000},
           "1119":{"name":"notebook",
                  "price":40,
                  "quantity": 20000},
           "1120":{"name":"file",
                  "price":70,
                  "quantity": 10000}}
class Company:
    def __init__(self):
        self.min_limit= 200
        self.max_limit= 5000
    def get_prodid(self,product):
        global product
        for i in list(product.keys()):
            if(product[i]["name"]==product):
                self.key = i
                return self.key
        else:
            return False
    def check_quantity(self,quantity):
        global product
        if(quantity>=self.min_limit and quantity<=self.max_limit):
            return True
        else:
            return False
    def calc_price(self,product,quantity):
        global product
        self.price = price_list[product]["price"]*quantity
        product[product][quantity] -= quantity
        return self.price
    def add_product(self,id,name,price,quantity):
        product[id]["name"]=name
        product[id]["quantity"]=quantity
        product[id]["price"]=price
    
obj = Company()
product = input("enter the product you want to buy: ")
prodid = obj.get_prodid(product)
if(prodid != False):
    quantity = int(input("enter quantity of product"))
    if(obj.check_quantity(quantity)):
        price= obj.calc_price(prodid,quantity)
        print("your bill is: ", price)
    else:
        print("Quantity should be between 200 - 5000")
else:
    print("please try to order the item from the below list")

# %%
product = {"1111":{"name":"pencil",
                  "price":10,
                  "quantity": 2000},
           "1112":{"name":"pen",
                  "price":20,
                  "quantity": 24000},
           "1113":{"name":"copy",
                  "price":30,
                  "quantity": 8000},
           "1114":{"name":"binding",
                  "price":40,
                  "quantity": 7000},
           "1115":{"name":"eraser",
                  "price":5,
                  "quantity": 6000},
           "1116":{"name":"sharpner",
                  "price":6,
                  "quantity": 4000},
           "1117":{"name":"prints",
                  "price":20,
                  "quantity": 9000},
           "1118":{"name":"stickers",
                  "price":25,
                  "quantity": 6000},
           "1119":{"name":"notebook",
                  "price":40,
                  "quantity": 20000},
           "1120":{"name":"file",
                  "price":70,
                  "quantity": 10000}}
product["1119"]["quantity"]
# Out:
# 20000
